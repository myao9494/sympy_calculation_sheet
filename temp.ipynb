# %%
! code .

# %% [markdown]
# ボルトの最小軸力計算　https://gijyutsu-keisan.com/webapp/mech/calc_thread/explain/explain2.php

# %% [markdown]
# $$
# Z=\frac{K_{e x} K_{b d}}{K_{e x}+K_{b d}}
# $$
# Z=(K_(ex)K_(bd))/(K_(ex)+K_(bd))
#
#
# $$
# \delta=\delta_{e x}+\delta_{b d}=\frac{K_{e x}+K_{b d}}{K_{e x} K_{b d}} F_{a x} \leftrightarrow F_{a x}=Z \delta
# $$
# delta=delta_(ex)+delta_(bd)=(K_(ex)+K_(bd))/(K_(ex)K_(bd))F_(ax)harrF_(ax)=Z delta
#
#
# $$
# \delta_{e x}=\frac{F_{a x}}{K_{e x}}, \delta_{b d}=\frac{F_{a x}}{K_{b d}}
# $$
# delta_(ex)=(F_(ax))/(K_(ex)),delta_(bd)=(F_(ax))/(K_(bd))
#
#
# $$
# \phi=\frac{K_{e x}}{K_{e x}+K_{b d}}
# $$
# phi=(K_(ex))/(K_(ex)+K_(bd))
#
#
# $$
# F_{e x}=F_{a x}+\frac{K_{e x}}{K_{e x}+W_{b d}} F_{t}=F_{a x}+\phi F_{t}
# $$
# F_(ex)=F_(ax)+(K_(ex))/(K_(ex)+W_(bd))F_(t)=F_(ax)+phiF_(t)
#
# $$
# \frac{1}{K_{b d}}=\sum_{i=1,2, \cdots} \frac{1}{K_{b d i}}
# $$
# (1)/(K_(bd))=sum_(i=1,2,cdots)(1)/(K_(bdi))
#
# $$
# \left\{\begin{array}{l}
# F_{t}=F_{e x}-F_{b d} \\
# F_{e x}=F_{a x}+K_{e x} \lambda \\
# F_{b d}=F_{a x}-K_{b d} \lambda
# \end{array}\right.
# $$
# {[F_(t)=F_(ex)-F_(bd)],[F_(ex)=F_(ax)+K_(ex)lambda],[F_(bd)=F_(ax)-K_(bd)lambda]:}
#
# $$
# D_{e}=\left\{\begin{array}{ll}
# D_{b d o} & \left(D_{b d o} \geq D_{f l}\right) \\
# D_{f l}+\alpha_{f} \frac{k}{10} t_{b d i} & \left(D_{b d o}<D_{f l}\right.
# \end{array}\right.
# $$
# D_(e)={[D_(bdo),(D_(bdo)>=D_(fl))],[D_(fl)+alpha_(f)(k)/( 10)t_(bdi),(D_(bdo)<D_(fl):}]:}
#
# $$
# k=1-\frac{1}{4}\left(3-\frac{D_{b d o}}{D_{f l}}\right)^{2}
# $$
# k=1-(1)/(4)(3-(D_(bdo))/(D_(fl)))^(2)
#
# $$
# K_{b d i}=\frac{\pi E_{b d i}}{4 t_{b d i}}\left(D_{e}^{2}-D_{b d h}^{2}\right)
# $$
# K_(bdi)=(piE_(bdi))/(4t_(bdi))(D_(e)^(2)-D_(bdh)^(2))
#
# $$
# \frac{1}{K_{e x}}=\sum_{i=a, b, c, d} \frac{1}{K_{i}}
# $$
# (1)/(K_(ex))=sum_(i=a,b,c,d)(1)/(K_(i))
#
# $$
# K_{d}=\frac{\pi D_{4}^{2} E_{e x}}{4(0.7 D)}
# $$
# K_(d)=(piD_(4)^(2)E_(ex))/(4(0.7 D))
#
# $$
# K_{c}=\frac{\pi D_{4}^{2} E_{e x}}{4 L_{c}}
# $$
# K_(c)=(piD_(4)^(2)E_(ex))/(4L_(c))
#
#
# $$
# K_{b}=\frac{\pi D_{a x}^{2} E_{e x}}{4 L_{b}}
# $$
# K_(b)=(piD_(ax)^(2)E_(ex))/(4L_(b))
#
#
# $$
# K_{a}=\frac{\pi D_{a x}^{2} E_{e x}}{4(0.6 D)}
# $$
# K_(a)=(piD_(ax)^(2)E_(ex))/(4(0.6 D))

# %% [markdown]
# $$
# \sigma_{e q}=\frac{T_{f}}{0.0425\left(1+\frac{1}{Q_{t q}}\right) D^{3}}
# $$
# sigma_(eq)=(T_(f))/(0.0425(1+(1)/(Q_(tq)))D^(3))
#
# $$
# T_{f}=k D F_{a x}[\mathrm{N} \cdot \mathrm{m}]
# $$
# T_(f)=kDF_(ax)[N*m]
#
# $$
# M_{s}=\frac{D_{f l e}}{2} \mu_{c} F_{a x s}
# $$
# M_(s)=(D_(fle))/(2)mu_(c)F_(axs)
#
# $$
# F_{a x s}=\max \left(\frac{F_{s}}{\mu_{c}}, \frac{2 M_{s}}{\mu_{c} D_{f l e}}\right)
# $$
# F_(axs)=max((F_(s))/(mu_(c)),(2M_(s))/(mu_(c)D_(fle)))
#
# $$
# F_{a x t}=(1-\phi) F_{t}
# $$
# F_(axt)=(1-phi)F_(t)
#
# $$
# F_{S}=\mu_{c} F_{a x s}
# $$
# F_(S)=mu_(c)F_(axs)
#
# $$
# (1-\phi) F_{t} \leq F_{a x t}
# $$
# (1-phi)F_(t)<=F_(axt)
#
# $$
# \Delta F_{a x 2}=Z \delta_{2} \quad(Z: \wedge \text { 夕リ係数 })
# $$
# DeltaF_(ax2)=Zdelta_(2)quad(Z:^^" 夕リ係数 ")
#
# $$
# \delta_{2}=\sum_{i} \alpha_{b d i} t_{b d i}-\alpha_{e x} \sum_{i} t_{b d i}
# $$
# delta_(2)=sum_(i)alpha_(bdi)t_(bdi)-alpha_(ex)sum_(i)t_(bdi)
#
# $$
# \Delta F_{a x 1}=Z \delta_{1} \quad(Z: \text { ヘ夕リ係数 })
# $$
# DeltaF_(ax1)=Zdelta_(1)quad(Z:" ヘ夕リ係数 ")
#
# $$
# \Delta F_{a x}=Z \delta
# $$
# DeltaF_(ax)=Z delta
#
# $$
# \delta_{1}=C_{s u r f}\left(R_{z i}+R_{z j}\right)
# $$
# delta_(1)=C_(surf)(R_(zi)+R_(zj))
#
# $$
# Z=\frac{K_{e x} K_{b d}}{K_{e x}+K_{b d}}
# $$
# Z=(K_(ex)K_(bd))/(K_(ex)+K_(bd))
#
# $$
# \delta=\delta_{e x}+\delta_{b d}=\frac{K_{e x}+K_{b d}}{K_{e x} K_{b d}} F_{a x} \leftrightarrow F_{a x}=Z \delta
# $$
# delta=delta_(ex)+delta_(bd)=(K_(ex)+K_(bd))/(K_(ex)K_(bd))F_(ax)harrF_(ax)=Z delta
